# %%
import pandas as pd

df = pd.read_csv('sampleParams.csv')
df.sort_values(by='priority', ascending=False, inplace=True)
df
# Out:
#      Parameter      value    unit  priority
# 2  temperature  [300,301]  kelvin       3.0
# 0      voltage    [0,1,2]       V       2.0
# 1        field    (0,0,0)       T       1.0
# 3       isInit     "init"     NaN       0.0
# 4     location    "earth"     NaN       NaN

# %%
df.priority
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    0.0
# Name: priority, dtype: float64
