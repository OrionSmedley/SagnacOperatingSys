# %%
from pymeasure.instruments.newport import ESP300
from pymeasure.instruments.keithley import Keithley2400
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2pointVoltageVSCurrent_2.csv')
plt.plot(df['Voltage'], df['leakage'])
df = pd.read_csv('C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2pointVoltageVSCurrent_3.csv')
plt.plot(df['Voltage'], df['leakage'])
df = pd.read_csv('C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_highvoltage_run5.csv')
plt.plot(df['Voltage'], df['leakage'])
df = pd.read_csv('C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_highvoltage_run6.csv')
plt.plot(df['Voltage'], df['leakage'])
plt.ylim(-1e-10, 1e-10)
plt.xlim(-100, 100)
# Out:
# (-100.0, 100.0)

# %%
# filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run1.csv'
# df = pd.read_csv(filename)
# plt.plot(df['Voltage'], df['leakage'])

# filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run2.csv'
# df = pd.read_csv(filename)
# plt.plot(df['Voltage'], df['leakage'])
# plt.axhline(0.2e-10)

# filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run3.csv'
# df = pd.read_csv(filename)
# plt.plot(df['Voltage'], df['leakage'], label = '80 to -80V')
# plt.axhline(0.2e-10)

filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run6.csv'
df = pd.read_csv(filename)
plt.plot(df['Voltage'], df['leakage'], label = '0 to -80V')
plt.axhline(0.2e-10)

filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run4.csv'
df = pd.read_csv(filename)
plt.plot(df['Voltage'], df['leakage'], label = '-80 to 80V')
plt.axhline(0.2e-10)

filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run5.csv'
df = pd.read_csv(filename)
plt.plot(df['Voltage'], df['leakage'], label = '80 to -80V')
plt.axhline(0.2e-10)

filename = 'C:/Users/Ralph Group/Documents/Data/TiffanyFilms/NiFerritePostPaterning/IV/gating2point2450_80V_run9.csv'
df = pd.read_csv(filename)
plt.plot(df['Voltage'], df['leakage'], label = '80 to -80V')
plt.axhline(0.2e-10)

plt.legend()
