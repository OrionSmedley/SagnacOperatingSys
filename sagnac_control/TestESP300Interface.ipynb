# %%
from pymeasure.instruments.newport import ESP300
from time import sleep

a= ESP300(10)
a.y.position

print(f" x: {a.x.position} y: {a.y.position} phi: {a.phi.position}")

a.phi.position = 135.0

sleep(3)
print(f" x: {a.x.position} y: {a.y.position} phi: {a.phi.position}")
# Out:
#  x: 24.42999 y: 24.72999 phi: 135.2
#  x: 24.42999 y: 24.72999 phi: 135.001
