# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
import numpy as np
import sys
import pymeasure
from pymeasure.instruments.keithley import keithley2400

# %%
k2400 = keithley2400("GPIB::10")

# %%
def apply_gate(Vcurrent=0, Vtarget):
    steps = int(np.absolute(Vtarget-Vcurrent)/0.1)
    k2400.ramp_to_voltage(Vtarget, steps, 0.1)

# %%
apply_gate(0,1)

# %%
k2400.current[1]
