# %%
from sagnac.ANC300 import ANC300
stepper = ANC300()
stepper.connect()
# Out:
# b'attocube ANC300 controller version 1.2.2-84 2022-09-06 17:30\r\nANC150 compatibillity console\r\n\r\n'

# %%
stepper.get_v(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stepper.get_v(4)
#
# File d:\Github\SagnacOperatingSys\sagnac_control\sagnac\ANC300.py:82, in ANC300.get_v(self, axis)
#      79 def get_v(self, axis):
#      80     """ Returns the voltage
#      81     """
# ---> 82     self.session.write("getv " + str(axis))
#      83     return self.session.read()
#
# File c:\ProgramData\anaconda3\Lib\telnetlib.py:291, in Telnet.write(self, buffer)
#     284 def write(self, buffer):
#     285     """Write a string to the socket, doubling any IAC characters.
#     286
#     287     Can block if the connection is blocked.  May raise
#     288     OSError if the connection is closed.
#     289
#     290     """
# --> 291     if IAC in buffer:
#     292         buffer = buffer.replace(IAC, IAC+IAC)
#     293     sys.audit("telnetlib.Telnet.write", self, buffer)
#
# ...

# %%
stepper.get_f(4)
# Out:
# b'getf 4'

# %%
anc300.go(b"getid")

# %%
stepper.stepu(6, 2) #pos X

# %%
stepper.stepd(6, 2) #neg X

# %%
stepper.stepu(5, 2) #pos Y

# %%
stepper.stepd(5, 2) #neg Y

# %%
import time
while True:
    time.sleep(0.2)
    stepper.stepd(4,1) #neg Z
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1059], line 3
#       1 import time
#       2 while True:
# ----> 3     time.sleep(0.2)
#       4     stepper.stepd(4,1)
#
# KeyboardInterrupt:

# %%
stepper.stepu(4,1) #pos ZI

# %%
while True:
    input(updo)

# %%
import numpy as np

# %%
field, sweep_field_azimuth, sweep_field_polar = -0.4, 0.0, 88.
bias_field_x, bias_field_y, bias_field_z = 0., 0., 0.

# %%
Bx = field*np.cos(np.deg2rad(sweep_field_azimuth))*np.sin(np.deg2rad(sweep_field_polar)) + bias_field_x
By = field*np.sin(np.deg2rad(sweep_field_azimuth))*np.sin(np.deg2rad(sweep_field_polar)) + bias_field_y
Bz = field*np.cos(np.deg2rad(sweep_field_polar)) + bias_field_z

# %%
print(Bx, By, Bz)
# Out:
# -0.39975633080763834 0.0 -0.013959798681000432

# %%
np.isclose()

# %%
if np.isclose(Bx_set,Bx_current, rtol=RTOL) and np.isclose(By_set,By_current,rtol=RTOL) and np.isclose(Bz_set, Bz_current, rtol=RTOL):
    log.info("Field is close to the setpoint")
    return True
else:
    log.info(f"{Bx_current}, {By_current}, {Bz_current}")
    # log.info("field is not close to the setpoint")
    return False

# %%
5e-3
# Out:
# 0.005

# %%
np.isclose(Bz, -0.014, 5e-3)
# Out:
# True

# %%
Bz
# Out:
# -0.013959798681000432
