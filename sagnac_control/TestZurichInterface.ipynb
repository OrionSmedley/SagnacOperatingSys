# %%
from zhinst.toolkit import Session

session = Session("localhost", hf2=True)

device = session.connect_device("DEV1004")

# %%
print(device['demods/4/order'])
print(type(device['demods/4/order']))
# Out:
# /dev1004/demods/4/order
# <class 'zhinst.toolkit.nodetree.node.Node'>

# %%
device['demods/4/order']()
# Out:
# 8

# %%
print( device['demods/4/x'] )
print( type(device['demods/4/x']) )
# Out:
# /dev1004/demods/4/x
# <class 'zhinst.toolkit.nodetree.node.Node'>

# %%
device['demods/4/x']()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 device['demods/4/x']()
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:557, in Node.__call__(self, value, deep, enum, parse, **kwargs)
#     514 """Call operator that either gets (empty) or gets the value of a node.
#     515
#     516 Args:
#    (...)
#     554         node.
#     555 """
#     556 if value is None:
# --> 557     return self._get(deep=deep, enum=enum, parse=parse, **kwargs)
#     558 return self._set(value, deep=deep, enum=enum, parse=parse, **kwargs)
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:656, in Node._get(self, deep, enum, parse, **kwargs)
#     654 if readable is False:
#     655     raise AttributeError(f"{self.node_info.path} is not readable.")
# ...

# %%
device.demods["*"].order()
# Out:
# {'/dev1004/demods/4/order': 8, '/dev1004/demods/5/order': 8, '/dev1004/demods/0/order': 8, '/dev1004/demods/2/order': 8, '/dev1004/demods/1/order': 8, '/dev1004/demods/3/order': 8}

# %%
device.demods[0].x.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 device.demods[0].x.sample()
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:557, in Node.__call__(self, value, deep, enum, parse, **kwargs)
#     514 """Call operator that either gets (empty) or gets the value of a node.
#     515
#     516 Args:
#    (...)
#     554         node.
#     555 """
#     556 if value is None:
# --> 557     return self._get(deep=deep, enum=enum, parse=parse, **kwargs)
#     558 return self._set(value, deep=deep, enum=enum, parse=parse, **kwargs)
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:656, in Node._get(self, deep, enum, parse, **kwargs)
#     654 if readable is False:
#     655     raise AttributeError(f"{self.node_info.path} is not readable.")
# ...

# %%
for i,j in   device.demods[3].sample():
    print(i)
    print(j )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 for i,j in   device.demods[3].sample():
#       2     print(i)
#       3     print(j )
#
# ValueError: too many values to unpack (expected 2)

# %%
nodelist = (list(device.child_nodes(recursive=True, leavesonly=True)))

# print the list of nodes that have getSample in them
for node in nodelist:
    if "getSample" in node:
        print(node)
        # print(device.get(node))
        # print("\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 5
#       3 # print the list of nodes that have getSample in them
#       4 for node in nodelist:
# ----> 5     if "getSample" in node:
#       6         print(node)
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:469, in Node.__contains__(self, k)
#     468 def __contains__(self, k):
# --> 469     return k in self._next_layer
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\helper.py:81, in lazy_property.__get__(self, instance, owner)
#      79 val = cache.get(self.attrname, _NOT_FOUND)
#      80 if val is _NOT_FOUND:
# ---> 81     val = self.func(instance)
#      82     try:
#      83         cache[self.attrname] = val
#
# ...

# %%
# list( device.child_nodes() )
list(device.demods[0].child_nodes())
device.demods.getSample()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 # list( device.child_nodes() )
#       2 list(device.demods[0].child_nodes())
# ----> 3 device.demods.getSample()
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:557, in Node.__call__(self, value, deep, enum, parse, **kwargs)
#     514 """Call operator that either gets (empty) or gets the value of a node.
#     515
#     516 Args:
#    (...)
#     554         node.
#     555 """
#     556 if value is None:
# --> 557     return self._get(deep=deep, enum=enum, parse=parse, **kwargs)
#     558 return self._set(value, deep=deep, enum=enum, parse=parse, **kwargs)
#
# File c:\Users\Ralph Group\anaconda3\envs\pymeasure\lib\site-packages\zhinst\toolkit\nodetree\node.py:656, in Node._get(self, deep, enum, parse, **kwargs)
#     654 if readable is False:
# ...

# %% [markdown]
# # old

# %%
from pymeasure.instruments.zurich import HF2LI

# %%
lockin = HF2LI(8005,1,1004)

# %%
lockin.disconnect()

# %%
lockin.sub(0)

# %%
dat_list = []
dat_list.append(lockin.poll_and_unpack(0.02, 100, [0], ['x','y'], ratio=False))
dat = {i : {comp : sum(dat_list[j][i][comp] for j in range(len(dat_list)))/len(dat_list) for comp in dat_list[0][i].keys()} for i in dat_list[0].keys()}

# %%
dat[0]['x'],
# Out:
# (4.336040334306987e-09,)
