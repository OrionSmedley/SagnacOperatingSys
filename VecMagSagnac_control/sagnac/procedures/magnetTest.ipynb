# %% [markdown]
# ### Old Code

# %%
import serial
import time

# Configuration
PORT = "COM5"  # Replace with the correct port, e.g., /dev/ttyUSB0 on Linux
BAUDRATE = 9600  # Replace with the correct baud rate (check documentation)
TIMEOUT = 2      # Timeout for reading responses

def connect_to_attocube():
    try:
        # Open the serial connection
        with serial.Serial(port=PORT, baudrate=BAUDRATE, timeout=TIMEOUT) as ser:
            print(f"Connected to Attocube APS100 on {PORT}")

            # Example: Send a command (Replace 'YOUR_COMMAND' with the actual command)
            command = "IOUT?\n"  # Commands often end with a newline
            ser.write(command.encode('utf-8'))
            print(f"Sent: {command.strip()}")
            
            # Wait for a response
            time.sleep(1)  # Wait briefly for the device to respond
            response = ser.read(ser.in_waiting or 1)  # Read available data
            print(f"Received: {response.decode('utf-8').strip()}")

    except serial.SerialException as e:
        print(f"Serial connection error: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
connect_to_attocube()
# Out:
# Connected to Attocube APS100 on COM5
# Sent: IOUT?
# Received: IOUT?
# 0.000kG

# %% [markdown]
# ### Magnet Control

# %% [markdown]
# #### Connect to x magnet

# %%
from pymeasure.instruments.attocube import APS100
mag = APS100('COM4')
mag.connect()
mag.send_command('REMOTE')
mag.disconnect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pymeasure.instruments.attocube import APS100
#       2 mag = APS100('COM4')
#       3 mag.connect()
#
# File d:\github\sagnacoperatingsys\pymeasuremod\pymeasure\instruments\__init__.py:26
#       1 #
#       2 # This file is part of the PyMeasure package.
#       3 #
#    (...)
#      22 # THE SOFTWARE.
#      23 #
#      25 from ..errors import RangeError, RangeException
# ---> 26 from .instrument import Instrument
#      27 from .mock import Mock
#      28 from .resources import list_resources
#
# File d:\github\sagnacoperatingsys\pymeasuremod\pymeasure\instruments\instrument.py:31
#      28 import numpy as np
#      30 from pymeasure.adapters import FakeAdapter
# ---> 31 from pymeasure.adapters.visa import VISAAdapter
#      32 from pymeasure.adapters import AmetekIPAdapter, DAQmxAdapter
#      34 log = logging.getLogger(__name__)
#
# File d:\github\sagnacoperatingsys\pymeasuremod\pymeasure\adapters\visa.py:28
#      25 import logging
#      27 import copy
# ---> 28 import visa
#      29 # import pyvisa as visa
#      30 import numpy as np
#
# ModuleNotFoundError: No module named 'visa'

# %% [markdown]
# #### Commands using Units specified on screen

# %%
mag.set_field(0.1)

# %%
mag.zero_field()

# %%
mag.send_command('SWEEP ZERO')
# Out:
# 'SWEEP ZERO'

# %%
mag.send_command('ULIM 27.777')
mag.send_command('SWEEP UP')
# Out:
# 'SWEEP UP'

# %%
mag.send_command('LLIM?')
mag.send_command('SWEEP DOWN')

# %%
mag.send_command('ERROR?')
# Out:
# '0'

# %% [markdown]
# ##### Set Field

# %%
# unit in kG
mag.set_field(-8)

# %%
mag.send_command('REMOTE')
mag.set_field(0)

# %% [markdown]
# ##### Check Field

# %%
mag.check_field(0.005)
# Out:
# True

# %%
mag2 = APS100('COM5')
mag2.connect()
mag2.disconnect()
# Out:
# Connected to APS100 on COM5
# Disconnected from APS100

# %%
mag2.send_command('CHAN?')
# Out:
# '1'

# %% [markdown]
# #### Y and Z magnet

# %%
from pymeasure.instruments.attocube import APS100
mag2 = APS100('COM5')
mag2.connect()
mag2.send_command('REMOTE')
# Out:
# Connected to APS100 on COM5
# 'REMOTE'

# %%
mag2.set_channel(1)
# Out:
# '1'

# %%
mag2.send_command('CHAN?')
# Out:
# '1'

# %%
mag2.set_field(1)

# %%
mag2.send_command('SWEEP ZERO')
# use sweep zero so it will be on stand by
# Out:
# 'SWEEP ZERO'

# %%
mag2.set_field(0)

# %%
mag2.send_command('LLIM?')
# Out:
# '-5.000kG'

# %%
mag2.set_field(8)

# %%
mag2.get_field()
# Out:
# 2.367

# %%
mag2.zero_field()
