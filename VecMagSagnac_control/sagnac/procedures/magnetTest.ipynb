# %% [markdown]
# ### Old Code

# %%
import serial
import time

# Configuration
PORT = "COM5"  # Replace with the correct port, e.g., /dev/ttyUSB0 on Linux
BAUDRATE = 9600  # Replace with the correct baud rate (check documentation)
TIMEOUT = 2      # Timeout for reading responses

def connect_to_attocube():
    try:
        # Open the serial connection
        with serial.Serial(port=PORT, baudrate=BAUDRATE, timeout=TIMEOUT) as ser:
            print(f"Connected to Attocube APS100 on {PORT}")

            # Example: Send a command (Replace 'YOUR_COMMAND' with the actual command)
            command = "IOUT?\n"  # Commands often end with a newline
            ser.write(command.encode('utf-8'))
            print(f"Sent: {command.strip()}")
            
            # Wait for a response
            time.sleep(1)  # Wait briefly for the device to respond
            response = ser.read(ser.in_waiting or 1)  # Read available data
            print(f"Received: {response.decode('utf-8').strip()}")

    except serial.SerialException as e:
        print(f"Serial connection error: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
connect_to_attocube()
# Out:
# Connected to Attocube APS100 on COM5
# Sent: IOUT?
# Received: IOUT?
# 0.000kG

# %% [markdown]
# ### Magnet Control

# %% [markdown]
# #### Connect to x magnet

# %%
# patch the old packages calling visa
# this is a hack to make the old packages work with pyvisa

#############################################################################################################################
import pyvisa

# Simulate the `visa` module as an alias for `pyvisa`
import sys

# Create a fake 'visa' module, which is essentially an alias for pyvisa
sys.modules['visa'] = pyvisa

# Optionally, map all attributes from pyvisa to visa (this is technically unnecessary because the alias works)
for attr in dir(pyvisa):
    setattr(sys.modules['visa'], attr, getattr(pyvisa, attr))

#############################################################################################################################

# %%
from pymeasure.instruments.attocube import APS100
mag = APS100('COM4')
mag.connect()
mag.send_command('REMOTE')
mag.disconnect()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# File d:\github\sagnacoperatingsys\pymeasuremod\pymeasure\instruments\attocube\aps100.py:30, in APS100.connect(self)
#      29 try:
# ---> 30     self.connection = serial.Serial(
#      31         port=self.port,
#      32         baudrate=self.baudrate,
#      33         timeout=self.timeout
#      34     )
#      35     print(f"Connected to APS100 on {self.port}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     243 if port is not None:
# --> 244     self.open()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#
# SerialException: could not open port 'COM4': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pymeasure.instruments.attocube import APS100
#       2 mag = APS100('COM4')
# ----> 3 mag.connect()
#       4 mag.send_command('REMOTE')
#       5 mag.disconnect()
#
# File d:\github\sagnacoperatingsys\pymeasuremod\pymeasure\instruments\attocube\aps100.py:37, in APS100.connect(self)
#      35     print(f"Connected to APS100 on {self.port}")
#      36 except serial.SerialException as e:
# ---> 37     raise ConnectionError(f"Failed to connect to APS100 on {self.port}: {e}")
#
# ConnectionError: Failed to connect to APS100 on COM4: could not open port 'COM4': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)

# %% [markdown]
# #### Commands using Units specified on screen

# %%
mag.set_field(0.1)

# %%
mag.zero_field()

# %%
mag.send_command('SWEEP ZERO')
# Out:
# 'SWEEP ZERO'

# %%
mag.send_command('ULIM 27.777')
mag.send_command('SWEEP UP')
# Out:
# 'SWEEP UP'

# %%
mag.send_command('LLIM?')
mag.send_command('SWEEP DOWN')

# %%
mag.send_command('ERROR?')
# Out:
# '0'

# %% [markdown]
# ##### Set Field

# %%
# unit in kG
mag.set_field(-8)

# %%
mag.send_command('REMOTE')
mag.set_field(0)

# %% [markdown]
# ##### Check Field

# %%
mag.check_field(0.005)
# Out:
# True

# %%
mag2 = APS100('COM5')
mag2.connect()
mag2.disconnect()
# Out:
# Connected to APS100 on COM5
# Disconnected from APS100

# %%
mag2.send_command('CHAN?')
# Out:
# '1'

# %% [markdown]
# #### Y and Z magnet

# %%
from pymeasure.instruments.attocube import APS100
mag2 = APS100('COM5')
mag2.connect()
mag2.send_command('REMOTE')
# Out:
# Connected to APS100 on COM5
# 'REMOTE'

# %%
mag2.set_channel(1)
# Out:
# '1'

# %%
mag2.send_command('CHAN?')
# Out:
# '1'

# %%
mag2.set_field(1)

# %%
mag2.send_command('SWEEP ZERO')
# use sweep zero so it will be on stand by
# Out:
# 'SWEEP ZERO'

# %%
mag2.set_field(0)

# %%
mag2.send_command('LLIM?')
# Out:
# '-5.000kG'

# %%
mag2.set_field(8)

# %%
mag2.get_field()
# Out:
# 2.367

# %%
mag2.zero_field()
