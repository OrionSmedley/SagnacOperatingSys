# %%
from aps100 import APS100

# %%
xmag = APS100('COM4')
xmag.connect()
# Out:
# Connected to APS100 on COM4

# %%
xmag.query_command('*IDN?')
# Out:
# 'Attocube,APS100,2301003,1.67,323'

# %%
xmag.get_field()
# Out:
# -0.0

# %%
xmag.set_field(0.00)

# %%
xmag.check_field(0.0)
# Out:
# False

# %%
ymag = APS100('COM5')
ymag.connect()
# Out:
# Connected to APS100 on COM5

# %%
ymag.set_channel(2)
# Out:
# '2'

# %%
ymag.set_field(0)

# %%
ymag.get_field()
# Out:
# 0.0
