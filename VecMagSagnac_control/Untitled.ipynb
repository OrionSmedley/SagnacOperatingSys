# %%
from sagnac.procedures.xy_scan_sagnac_procedure import xy_scan_sagnac_procedure
from sagnac.procedures.XYScanProcedure import sagnacXYScanProcedure
# Out:
# C:\Users\Ralph Group\anaconda3\lib\site-packages\pyvisa-1.11.3-py3.8.egg\visa.py:13: FutureWarning: The visa module provided by PyVISA is being deprecated. You can replace `import visa` by `import pyvisa as visa` to achieve the same effect.
#
# The reason for the deprecation is the possible conflict with the visa package provided by the https://github.com/visa-sdk/visa-python which can result in hard to debug situations.
#   warnings.warn(

# %%
a = xy_scan_sagnac_procedure()

# %%
a
# Out:
# <xy_scan_sagnac_procedure(status=Queued,parameters_are_set=False)>

# %%
b = sagnacXYScanProcedure()

# %%
b
# Out:
# <sagnacXYScanProcedure(status=Queued,parameters_are_set=False)>

# %%
hasattr(a, 'DATA_COLUMNS')
# Out:
# True

# %%
type(a.DATA_COLUMNS[0])
# Out:
# str

# %%
type(b.DATA_COLUMNS[0])
# Out:
# str

# %%
a.DATA_COLUMNS
# Out:
# ['ThetaK',
#  'X1',
#  'Y1',
#  'X2',
#  'Y2',
#  'DeltaThetaK',
#  'DeltaX1',
#  'DeltaY1',
#  'TX1',
#  'TY1',
#  'TX2',
#  'TY2',
#  'step',
#  'elapsed_time']

# %%
b.DATA_COLUMNS
# Out:
# ['ThetaK',
#  'X1',
#  'Y1',
#  'X2',
#  'Y2',
#  'DeltaThetaK',
#  'DeltaX1',
#  'DeltaY1',
#  'TX1',
#  'TY1',
#  'TX2',
#  'TY2',
#  'step',
#  'elapsed_time']
