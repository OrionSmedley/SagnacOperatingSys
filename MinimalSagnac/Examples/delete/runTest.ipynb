# %%
from instruments.sagnac1 import magnet

magnet.phi = 0
magnet.theta =0

# %%
magnet.field = 0

# %%
from instruments.sagnac1 import myHF2LI

myHF2LI.demods[3].sample()["x"]
# Out:
# array([-5.30314191e-07])

# %%
import pandas as pd
thing = pd.read_csv("deletable/initial.csv", comment = ";")
thing["yoink"] = thing[" dem(3)['x'] # X1"]

# %%
import plotly.express as px
fig = px.scatter(thing, y="yoink")
fig.show()

# %%
import numpy as np

# Add a sine wave column to the dataframe
thing['sine_wave'] = np.sin(thing['magnet.field'])

# Plot the sine wave
fig_sine = px.line(thing, x='magnet.field', y='sine_wave', title='Sine Wave Plot')
fig_sine.show()
