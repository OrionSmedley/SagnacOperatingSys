# %%
def plus(a,b):
    return a+b

# %%
a,b = q

# %%
b
# Out:
# 2

# %%
q= (1,2)

# %%
plus(*q)
# Out:
# 3

# %%
[1,2,3],[3,2,1]

# %%
def f():
    return np.random.rand()

# %%
f()
# Out:
# 0.17772180991346354

# %%
import numpy as np
f = np.nan

# %%
f
# Out:
# nan

# %%
def f():
    return np.random.rand()

# %%
f()
# Out:
# 0.0040350052930421265
