# %%
import numpy as np
import pandas as pd
import plotly.express as px
def rename_columns(df):
    df.columns = [col.split('#')[-1].strip() if '#' in col else col.strip() for col in df.columns]
    return df

# %%
test = rename_columns(pd.read_csv("VItrace.csv", comment = ";"))
print(list(test.columns))
px.line(test, x='keith.source_current', y='keith.voltage',color="ist.voltage",shape=
# Out:
# ['repeat', 'time.time', 'keith.source_current', 'keith.voltage']

# %% [markdown]
# # Auto Refresh version

# %%
# for autoRefresh plots
from IPython.display import clear_output
import time

while True:

    test = rename_columns(pd.read_csv("VItrace.csv", comment = ";"))
    print(list(test.columns))
    px.line(test, x='keith.source_current', y='keith.voltage',color="repeat").show()

    time.sleep(1)
    clear_output(wait=True)
# Out:
# ['repeat', 'keith.source_current', 'keith.voltage']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 11
#       8 print(list(test.columns))
#       9 px.line(test, x='keith.source_current', y='keith.voltage',color="repeat").show()
# ---> 11 time.sleep(1)
#      12 clear_output(wait=True)
#
# KeyboardInterrupt:
