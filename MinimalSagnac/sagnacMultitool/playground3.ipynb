# %%
# User instructions: import the myHF2LI and magnet objects for the sagnac interferometer





# patch the old packages calling visa
# this is a hack to make the old packages work with pyvisa

#############################################################################################################################
import pyvisa

# Simulate the `visa` module as an alias for `pyvisa`
import sys

# Create a fake 'visa' module, which is essentially an alias for pyvisa
sys.modules['visa'] = pyvisa

# Optionally, map all attributes from pyvisa to visa (this is technically unnecessary because the alias works)
for attr in dir(pyvisa):
    setattr(sys.modules['visa'], attr, getattr(pyvisa, attr))

#############################################################################################################################

# %% [markdown]
# # Lock in

# %%
from aparatus.sagnac3 import myHF2LI

# %%
myHF2LI.setTc(0.1)

# %%
myHF2LI.sigouts[1].amplitudes[7-1](0)

# %%
myHF2LI.ac(0.005)

# %%
myHF2LI.dem(3)["x"]

# %%
myHF2LI.get_vout(1,6)

# %%
from pymeasure.instruments.zurich import HF2LI
pyHF2LI = HF2LI(8005, 1, 18338)

# %%
[pyHF2LI.get_vout(1,a) *10 for a in range(8)]

# %% [markdown]
# # Laser

# %%
from aparatus.drivers.LDC3900 import LaserDriver
laser = LaserDriver()

# %%
callable(laser.LDI)

# %%
from aparatus.sagnac3 import laser
laser.LDI = 143

# %% [markdown]
# # Keithley

# %%
from aparatus.sagnac3 import keith1, keith2

# %%
keith1.source_current = 2e-6
keith1.source_current

# %%
keith1.voltage[0]

# %%
keith2.voltage[0]

# %%
from pymeasure.instruments.keithley import Keithley2400
keithley = Keithley2400("GPIB::26")

# %%
# keithley.apply_current()                # Sets up to source current
# keithley.source_current_range = 10e-3   # Sets the source current range to 10 mA

# %%
keithley.source_current

# %%
keithley.voltage

# %%
keithley.compliance_voltage = 10        # Sets the compliance voltage to 10 V
keithley.source_current = 0             # Sets the source current to 0 mA
keithley.enable_source()                # Enables the source output

keithley.measure_voltage()              # Sets up to measure voltage

# keithley.ramp_to_current(5e-3)          # Ramps the current to 5 mA
print(keithley.voltage)

# %% [markdown]
# # OWON

# %%
import vds1022 as owon

dev = owon.VDS1022(debug=0)
dev.set_channel(owon.CH1, range='10v', probe='x1')
frames = dev.fetch()
print("%s Vrms" % frames.ch1.rms())

# %%
dev.fetch().ch1.rms()

# %% [markdown]
# # Atto cube

# %% [markdown]
# ## Stepper

# %%
from aparatus.sagnac3 import stepper
# Out:
# 2025-01-15 16:08:57,164 - WARNING - Failed to import vxi11 package, which is required for the VXI11Adapter
# sagnac3.0: no owon

# %%
stepper.stepz(-5)

# %% [markdown]
# ## Temperature controller

# %%
from aparatus.sagnac3 import atto

# %%
atto.sample.getTemperature()

# %%
atto.pressures.getCryoInPressure()

# %%
print( atto.condenser.getTemperature() ) 
print( atto.vti.getTemperature() ) 
atto.sample.getTemperature()

# %% [markdown]
# ## Mag normal

# %%
from aparatus.sagnac3 import mag
mag.connect()
# Out:
# 2025-01-21 11:24:38,702 - WARNING - Failed to import vxi11 package, which is required for the VXI11Adapter
# Connected to APS100 on COM4
# Connected to APS100 on COM5
# conecting. The field is 1.7442032565042411

# %%
mag.B = 0

# %%
mag.Bx
# Out:
# -0.0

# %%
mag.setSafe_wait()
# Out:
# waiting for z to ramp down 7.0254974365234375
# waiting for z to ramp down 12.643285036087036
# waiting for z to ramp down 18.460912466049194
# waiting for mag for 25.488173246383667
# waiting for mag for 30.303831815719604
# waiting for mag for 33.02056121826172
# waiting for mag for 35.73678994178772
# waiting for mag for 38.452675580978394
# waiting for mag for 42.0682954788208
# waiting for mag for 45.68538212776184
# waiting for mag for 50.70559000968933
# waiting for mag for 54.32188153266907
# waiting for mag for 57.83746337890625

# %% [markdown]
# ### Old normal

# %%
mag.check_field_cartesian(0, 0, 0, 10-3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mag.check_field_cartesian(0, 0, 0, 10-3)
#
# NameError: name 'mag' is not defined

# %%
# mag.get_field_cartesian()
mag.setSafe_wait_cart(1.5, 1.5, 0.5)
# Out:
# Bz initial: (1.2, 1.2, 0.8)
# entering if
# waiting for z to ramp down
# waiting for mag for 4.723966121673584
# waiting for z to ramp down
# waiting for mag for 9.345337629318237
# waiting for z to ramp down
# waiting for mag for 12.962875604629517
# waiting for z to ramp down
# waiting for mag for 22.78692388534546
# waiting for z to ramp down
# waiting for mag for 28.609389305114746
# waiting for mag for 36.841108083724976
# waiting for mag for 43.86393451690674
# waiting for mag for 47.685625076293945
# waiting for mag for 54.60860228538513
# waiting for mag for 58.3268358707428
# waiting for mag for 61.04801154136658
# waiting for mag for 63.76628828048706
# waiting for mag for 67.28334474563599

# %%
mag.setSafe_wait_polar(0.1,90,1.27)
#+Bx is 0deg azimuthal, +By is 90deg azimuthal (90deg polar), -Bx is 180deg azimuthal, -By is 270deg azimuthal, +Bz is 0deg polar

# %%
mag.phi_set

# %%
mag.setSafeWaitTheta(45)

# %%
mag.get_field_cartesian()

# %%
mag.setSafeWaitBz(0.1)

# %%
#+Bx is 0deg azimuthal, +By is 90deg azimuthal (90deg polar), -Bx is 180deg azimuthal, -By is 270deg azimuthal, +Bz is 0deg polar
mag.setSafe_wait_polar(0,0, 0) 
mag.get_field_polar()
mag.get_field_cartesian()
# Out:
# waiting for mag for 6.0212342739105225
# waiting for mag for 9.739377737045288
# waiting for mag for 13.557152271270752
# waiting for mag for 19.577314376831055
# waiting for mag for 22.39574384689331
# waiting for mag for 25.21324324607849
# waiting for mag for 28.93096399307251
# waiting for mag for 32.64801597595215
# waiting for mag for 35.26371359825134
# waiting for mag for 42.08159804344177
# waiting for mag for 45.69763422012329
# waiting for mag for 51.315021991729736
# waiting for mag for 58.1335768699646
# waiting for mag for 61.75042772293091
# waiting for mag for 67.76875400543213
# waiting for mag for 71.387033700943
# waiting for mag for 74.00461268424988
# waiting for mag for 77.62292551994324
# waiting for mag for 85.04457116127014
# waiting for mag for 87.66124510765076
# waiting for mag for 90.27882361412048
# waiting for mag for 93.89466714859009
# waiting for mag for 100.51270794868469
# waiting for mag for 103.12888240814209
# waiting for mag for 105.74720621109009
# waiting for mag for 108.364825963974
# waiting for mag for 111.98160219192505
# waiting for mag for 115.59759187698364
# waiting for mag for 119.21503901481628
# waiting for mag for 121.83147406578064
# waiting for mag for 128.4511456489563
# waiting for mag for 134.06989192962646
# waiting for mag for 136.6859154701233
# waiting for mag for 140.30260157585144
# waiting for mag for 143.91959929466248
# waiting for mag for 150.94030046463013
# waiting for mag for 154.55534863471985
# waiting for mag for 159.1730980873108
# waiting for mag for 162.7903344631195
# waiting for mag for 167.40603399276733
# waiting for mag for 171.02240657806396
# waiting for mag for 174.6382339000702
# waiting for mag for 177.25401830673218
# waiting for mag for 183.0732102394104
# waiting for mag for 185.68829894065857
# waiting for mag for 190.50504970550537
# waiting for mag for 195.32234716415405
# waiting for mag for 198.93753623962402
# waiting for mag for 202.55538034439087
# waiting for mag for 208.1733627319336
# waiting for mag for 210.79094099998474
# waiting for mag for 214.6089470386505
# waiting for mag for 217.22542428970337
# waiting for mag for 220.8421983718872
# waiting for mag for 224.45993447303772
# waiting for mag for 229.17698407173157
# (0.0, 0.0, 0.001)

# %%
print(mag.B_set)
print(mag.phi_set)
print(mag.theta_set)

# %%
import numpy as np
[np.arange(0,360,10)]*2

# %%
mag.setSafeWaitPhi(90)

# %%
mag.setSafeWaitTheta(0)

# %% [markdown]
# ### Not sure what this is

# %%
import atto_device.CRYO2100 as cr

device = cr("192.168.1.1")
device.connect()
device.condenser.getTemperature()
from aparatus.drivers.magnet_usbCom import vectorMagnetFullUSB
import atto_device.CRYO2100 as cr
mag = vectorMagnetFullUSB()
mag.connect()

mag.safeWaitCart(0.01,0.01,0.02)

# %%
# import sys
# module_dir = r"D:\Github\SagnacOperatingSys\VecMagSagnac_control"
# sys.path.append(module_dir)
# from sagnac.custom_instruments import vectorMagnetFullUSB
# mag = vectorMagnetFullUSB()
# mag.connect()

# %% [markdown]
# ## Mag_HighZ

# %%
from aparatus.sagnac3 import mag_highZ , atto
mag_highZ.connect_highZ()

# %%
mag_highZ.setSafe_wait_highZ(1.4)

# %% [markdown]
# ### dumy high z

# %%
import sys
module_dir = r"D:\Github\SagnacOperatingSys\VecMagSagnac_control"
sys.path.append(module_dir)
from sagnac.custom_instruments import vectorMagnetFullUSB_highZ
mag_highZ = vectorMagnetFullUSB_highZ()
mag_highZ.connect_highZ()

# %%
mag_highZ.set_field_highZ(2.2)

# %%
mag_highZ.get_field_highZ()
