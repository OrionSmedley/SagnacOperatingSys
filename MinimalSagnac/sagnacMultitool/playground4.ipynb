# %%
# User instructions: import the myHF2LI and magnet objects for the sagnac interferometer





# patch the old packages calling visa
# this is a hack to make the old packages work with pyvisa

#############################################################################################################################
import pyvisa

# Simulate the `visa` module as an alias for `pyvisa`
import sys

# Create a fake 'visa' module, which is essentially an alias for pyvisa
sys.modules['visa'] = pyvisa

# Optionally, map all attributes from pyvisa to visa (this is technically unnecessary because the alias works)
for attr in dir(pyvisa):
    setattr(sys.modules['visa'], attr, getattr(pyvisa, attr))

#############################################################################################################################

# %% [markdown]
# IP addresses for each device:
#
# TM-622: 169.254.62.184
#
# Lake Shore 336: 169.254.62.185
#
# Z coil: 169.254.62.187
#
# X and Y coil: 169.254.62.188

# %% [markdown]
# # TM-620 Temp Monitor

# %%
from aparatus.sagnac4 import TM620
# Out:
# 2025-04-29 18:07:38,080 - WARNING - Failed to import vxi11 package, which is required for the VXI11Adapter

# %%
TM620.channel
# Out:
# 'a'

# %%
TM620.Tmag
# Out:
# 4.04

# %%
TM620.Tshield
# Out:
# 50.16

# %% [markdown]
# # Lake Shore 336

# %%
from aparatus.sagnac4 import LK336

# %%
LK336.query("*IDN?")
# Out:
# 'LSCI,MODEL336,LSA2NK0/#######,3.0'

# %%
LK336.get_sample_temp()
# Out:
# 193.131

# %%
LK336.get_vti_temp()
# Out:
# 199.999

# %%
LK336.set_vti_temp(200)
# Out:
# VTI Heater Limit Set to 200.0 K
# VTI Heater Range set to 0
# Waiting for VTI to cool from 216.2K to 200.0K
# Waiting for VTI to cool from 216.08K to 200.0K
# Waiting for VTI to cool from 215.98K to 200.0K
# Waiting for VTI to cool from 215.87K to 200.0K
# Waiting for VTI to cool from 215.76K to 200.0K
# Waiting for VTI to cool from 215.67K to 200.0K
# Waiting for VTI to cool from 215.55K to 200.0K
# Waiting for VTI to cool from 215.44K to 200.0K
# Waiting for VTI to cool from 215.34K to 200.0K
# Waiting for VTI to cool from 215.24K to 200.0K
# Waiting for VTI to cool from 215.12K to 200.0K
# Waiting for VTI to cool from 215.02K to 200.0K
# Waiting for VTI to cool from 214.93K to 200.0K
# Waiting for VTI to cool from 214.81K to 200.0K
# Waiting for VTI to cool from 214.73K to 200.0K
# Waiting for VTI to cool from 214.61K to 200.0K
# Waiting for VTI to cool from 214.52K to 200.0K
# Waiting for VTI to cool from 214.4K to 200.0K
# Waiting for VTI to cool from 214.31K to 200.0K
# Waiting for VTI to cool from 214.21K to 200.0K
# Waiting for VTI to cool from 214.1K to 200.0K
# Waiting for VTI to cool from 214.01K to 200.0K
# Waiting for VTI to cool from 213.89K to 200.0K
# Waiting for VTI to cool from 213.8K to 200.0K
# Waiting for VTI to cool from 213.7K to 200.0K
# Waiting for VTI to cool from 213.59K to 200.0K
# Waiting for VTI to cool from 213.5K to 200.0K
# Waiting for VTI to cool from 213.4K to 200.0K
# Waiting for VTI to cool from 213.29K to 200.0K
# Waiting for VTI to cool from 213.2K to 200.0K
# Waiting for VTI to cool from 213.1K to 200.0K
# Waiting for VTI to cool from 213.0K to 200.0K
# Waiting for VTI to cool from 212.9K to 200.0K
# Waiting for VTI to cool from 212.8K to 200.0K
# Waiting for VTI to cool from 212.7K to 200.0K
# Waiting for VTI to cool from 212.6K to 200.0K
# Waiting for VTI to cool from 212.51K to 200.0K
# Waiting for VTI to cool from 212.4K to 200.0K
# Waiting for VTI to cool from 212.3K to 200.0K
# Waiting for VTI to cool from 212.21K to 200.0K
# Waiting for VTI to cool from 212.11K to 200.0K
# Waiting for VTI to cool from 212.02K to 200.0K
# Waiting for VTI to cool from 211.92K to 200.0K
# Waiting for VTI to cool from 211.82K to 200.0K
# Waiting for VTI to cool from 211.73K to 200.0K
# Waiting for VTI to cool from 211.63K to 200.0K
# Waiting for VTI to cool from 211.54K to 200.0K
# Waiting for VTI to cool from 211.45K to 200.0K
# Waiting for VTI to cool from 211.35K to 200.0K
# Waiting for VTI to cool from 211.26K to 200.0K
# Waiting for VTI to cool from 211.16K to 200.0K
# Waiting for VTI to cool from 211.07K to 200.0K
# Waiting for VTI to cool from 210.98K to 200.0K
# Waiting for VTI to cool from 210.89K to 200.0K
# Waiting for VTI to cool from 210.8K to 200.0K
# Waiting for VTI to cool from 210.7K to 200.0K
# Waiting for VTI to cool from 210.62K to 200.0K
# Waiting for VTI to cool from 210.53K to 200.0K
# Waiting for VTI to cool from 210.44K to 200.0K
# Waiting for VTI to cool from 210.34K to 200.0K
# Waiting for VTI to cool from 210.25K to 200.0K
# Waiting for VTI to cool from 210.17K to 200.0K
# Waiting for VTI to cool from 210.07K to 200.0K
# Waiting for VTI to cool from 209.99K to 200.0K
# VTI Heater Range set to 3
# Waiting for VTI to go from 209.89K to 200.0K
# Waiting for VTI to go from 209.8K to 200.0K
# Waiting for VTI to go from 209.72K to 200.0K
# Waiting for VTI to go from 209.62K to 200.0K
# Waiting for VTI to go from 209.54K to 200.0K
# Waiting for VTI to go from 209.45K to 200.0K
# Waiting for VTI to go from 209.36K to 200.0K
# Waiting for VTI to go from 209.27K to 200.0K
# Waiting for VTI to go from 209.19K to 200.0K
# Waiting for VTI to go from 209.1K to 200.0K
# Waiting for VTI to go from 209.02K to 200.0K
# Waiting for VTI to go from 208.92K to 200.0K
# Waiting for VTI to go from 208.84K to 200.0K
# Waiting for VTI to go from 208.74K to 200.0K
# Waiting for VTI to go from 208.66K to 200.0K
# Waiting for VTI to go from 208.57K to 200.0K
# Waiting for VTI to go from 208.5K to 200.0K
# Waiting for VTI to go from 208.4K to 200.0K
# Waiting for VTI to go from 208.32K to 200.0K
# Waiting for VTI to go from 208.23K to 200.0K
# Waiting for VTI to go from 208.15K to 200.0K
# Waiting for VTI to go from 208.07K to 200.0K
# Waiting for VTI to go from 207.97K to 200.0K
# Waiting for VTI to go from 207.89K to 200.0K
# Waiting for VTI to go from 207.8K to 200.0K
# Waiting for VTI to go from 207.72K to 200.0K
# Waiting for VTI to go from 207.63K to 200.0K
# Waiting for VTI to go from 207.55K to 200.0K
# Waiting for VTI to go from 207.46K to 200.0K
# Waiting for VTI to go from 207.37K to 200.0K
# Waiting for VTI to go from 207.3K to 200.0K
# Waiting for VTI to go from 207.22K to 200.0K
# Waiting for VTI to go from 207.13K to 200.0K
# Waiting for VTI to go from 207.04K to 200.0K
# Waiting for VTI to go from 206.97K to 200.0K
# Waiting for VTI to go from 206.89K to 200.0K
# Waiting for VTI to go from 206.8K to 200.0K
# Waiting for VTI to go from 206.72K to 200.0K
# Waiting for VTI to go from 206.64K to 200.0K
# Waiting for VTI to go from 206.55K to 200.0K
# Waiting for VTI to go from 206.47K to 200.0K
# Waiting for VTI to go from 206.39K to 200.0K
# Waiting for VTI to go from 206.32K to 200.0K
# Waiting for VTI to go from 206.24K to 200.0K
# Waiting for VTI to go from 206.15K to 200.0K
# Waiting for VTI to go from 206.08K to 200.0K
# Waiting for VTI to go from 205.99K to 200.0K
# Waiting for VTI to go from 205.92K to 200.0K
# Waiting for VTI to go from 205.83K to 200.0K
# Waiting for VTI to go from 205.76K to 200.0K
# Waiting for VTI to go from 205.68K to 200.0K
# Waiting for VTI to go from 205.59K to 200.0K
# Waiting for VTI to go from 205.52K to 200.0K
# Waiting for VTI to go from 205.44K to 200.0K
# Waiting for VTI to go from 205.36K to 200.0K
# Waiting for VTI to go from 205.29K to 200.0K
# Waiting for VTI to go from 205.2K to 200.0K
# Waiting for VTI to go from 205.14K to 200.0K
# Waiting for VTI to go from 205.04K to 200.0K
# Waiting for VTI to go from 204.98K to 200.0K
# Waiting for VTI to go from 204.89K to 200.0K
# Waiting for VTI to go from 204.82K to 200.0K
# Waiting for VTI to go from 204.74K to 200.0K
# Waiting for VTI to go from 204.66K to 200.0K
# Waiting for VTI to go from 204.59K to 200.0K
# Waiting for VTI to go from 204.51K to 200.0K
# Waiting for VTI to go from 204.43K to 200.0K
# Waiting for VTI to go from 204.36K to 200.0K
# Waiting for VTI to go from 204.28K to 200.0K
# Waiting for VTI to go from 204.2K to 200.0K
# Waiting for VTI to go from 204.14K to 200.0K
# Waiting for VTI to go from 204.07K to 200.0K
# Waiting for VTI to go from 203.98K to 200.0K
# Waiting for VTI to go from 203.9K to 200.0K
# Waiting for VTI to go from 203.83K to 200.0K
# Waiting for VTI to go from 203.76K to 200.0K
# Waiting for VTI to go from 203.68K to 200.0K
# Waiting for VTI to go from 203.6K to 200.0K
# Waiting for VTI to go from 203.52K to 200.0K
# Waiting for VTI to go from 203.45K to 200.0K
# Waiting for VTI to go from 203.38K to 200.0K
# Waiting for VTI to go from 203.3K to 200.0K
# Waiting for VTI to go from 203.24K to 200.0K
# Waiting for VTI to go from 203.16K to 200.0K
# Waiting for VTI to go from 203.09K to 200.0K
# Waiting for VTI to go from 203.01K to 200.0K
# Waiting for VTI to go from 202.93K to 200.0K
# Waiting for VTI to go from 202.86K to 200.0K
# Waiting for VTI to go from 202.78K to 200.0K
# Waiting for VTI to go from 202.72K to 200.0K
# Waiting for VTI to go from 202.64K to 200.0K
# Waiting for VTI to go from 202.56K to 200.0K
# Waiting for VTI to go from 202.49K to 200.0K
# Waiting for VTI to go from 202.41K to 200.0K
# Waiting for VTI to go from 202.35K to 200.0K
# Waiting for VTI to go from 202.27K to 200.0K
# Waiting for VTI to go from 202.2K to 200.0K
# Waiting for VTI to go from 202.13K to 200.0K
# Waiting for VTI to go from 202.05K to 200.0K
# Waiting for VTI to go from 201.98K to 200.0K
# Waiting for VTI to go from 201.92K to 200.0K
# Waiting for VTI to go from 201.84K to 200.0K
# Waiting for VTI to go from 201.78K to 200.0K
# Waiting for VTI to go from 201.7K to 200.0K
# Waiting for VTI to go from 201.62K to 200.0K
# Waiting for VTI to go from 201.55K to 200.0K
# Waiting for VTI to go from 201.49K to 200.0K
# Waiting for VTI to go from 201.41K to 200.0K
# Waiting for VTI to go from 201.34K to 200.0K
# Waiting for VTI to go from 201.27K to 200.0K
# Waiting for VTI to go from 201.21K to 200.0K
# Waiting for VTI to go from 201.14K to 200.0K
# Waiting for VTI to go from 201.07K to 200.0K
# Waiting for VTI to go from 201.0K to 200.0K
# Waiting for VTI to go from 200.92K to 200.0K
# Waiting for VTI to go from 200.86K to 200.0K
# Waiting for VTI to go from 200.8K to 200.0K
# Waiting for VTI to go from 200.74K to 200.0K
# Waiting for VTI to go from 200.66K to 200.0K
# Waiting for VTI to go from 200.59K to 200.0K
# Waiting for VTI to go from 200.51K to 200.0K
# Waiting for VTI to go from 200.45K to 200.0K
# Waiting for VTI to go from 200.38K to 200.0K
# Waiting for VTI to go from 200.32K to 200.0K
# Waiting for VTI to go from 200.25K to 200.0K
# Waiting for VTI to go from 200.19K to 200.0K
# Waiting for VTI to go from 200.12K to 200.0K
# Waiting for VTI to go from 200.05K to 200.0K
# Waiting for VTI to go from 199.99K to 200.0K
# Waiting for VTI to go from 199.91K to 200.0K
# Waiting for VTI to go from 199.85K to 200.0K
# Waiting for VTI to go from 199.78K to 200.0K
# Waiting for VTI to go from 199.71K to 200.0K
# Waiting for VTI to go from 199.66K to 200.0K
# Waiting for VTI to go from 199.58K to 200.0K
# Waiting for VTI to go from 199.52K to 200.0K
# Waiting for VTI to go from 199.46K to 200.0K
# Waiting for VTI to go from 199.41K to 200.0K
# Waiting for VTI to go from 199.35K to 200.0K
# Waiting for VTI to go from 199.31K to 200.0K
# Waiting for VTI to go from 199.25K to 200.0K
# Waiting for VTI to go from 199.21K to 200.0K
# Waiting for VTI to go from 199.17K to 200.0K
# Waiting for VTI to go from 199.14K to 200.0K
# Waiting for VTI to go from 199.11K to 200.0K
# Waiting for VTI to go from 199.09K to 200.0K
# Waiting for VTI to go from 199.07K to 200.0K
# Waiting for VTI to go from 199.06K to 200.0K
# Waiting for VTI to go from 199.04K to 200.0K
# Waiting for VTI to go from 199.04K to 200.0K
# Waiting for VTI to go from 199.06K to 200.0K
# Waiting for VTI to go from 199.06K to 200.0K
# Waiting for VTI to go from 199.07K to 200.0K
# Waiting for VTI to go from 199.09K to 200.0K
# Waiting for VTI to go from 199.11K to 200.0K
# Waiting for VTI to go from 199.14K to 200.0K
# Waiting for VTI to go from 199.17K to 200.0K
# Waiting for VTI to go from 199.2K to 200.0K
# Waiting for VTI to go from 199.24K to 200.0K
# Waiting for VTI to go from 199.28K to 200.0K
# Waiting for VTI to go from 199.32K to 200.0K
# Waiting for VTI to go from 199.35K to 200.0K
# Waiting for VTI to go from 199.39K to 200.0K
# Waiting for VTI to go from 199.43K to 200.0K
# Waiting for VTI to go from 199.47K to 200.0K
# Waiting for VTI to go from 199.51K to 200.0K
# Waiting for VTI to go from 199.55K to 200.0K
# Waiting for VTI to go from 199.59K to 200.0K
# Waiting for VTI to go from 199.64K to 200.0K
# Waiting for VTI to go from 199.67K to 200.0K
# Waiting for VTI to go from 199.71K to 200.0K
# Waiting for VTI to go from 199.74K to 200.0K
# Waiting for VTI to go from 199.77K to 200.0K
# Waiting for VTI to go from 199.81K to 200.0K
# Waiting for VTI to go from 199.83K to 200.0K
# Waiting for VTI to go from 199.86K to 200.0K
# Waiting for VTI to go from 199.88K to 200.0K
# Waiting for VTI to go from 199.91K to 200.0K
# Waiting for VTI to go from 199.93K to 200.0K
# Waiting for VTI to go from 199.96K to 200.0K
# Waiting for VTI to go from 199.97K to 200.0K
# Waiting for VTI to go from 199.99K to 200.0K
# Waiting for VTI to go from 200.01K to 200.0K
# Waiting for VTI to go from 200.02K to 200.0K
# Waiting for VTI to go from 200.03K to 200.0K
# Waiting for VTI to go from 200.03K to 200.0K
# Waiting for VTI to go from 200.04K to 200.0K
# Waiting for VTI to go from 200.05K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.07K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.07K to 200.0K
# Waiting for VTI to go from 200.07K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.06K to 200.0K
# Waiting for VTI to go from 200.05K to 200.0K
# Waiting for VTI to go from 200.05K to 200.0K
# Waiting for VTI to go from 200.04K to 200.0K
# Waiting for VTI to go from 200.03K to 200.0K
# Waiting for VTI to go from 200.03K to 200.0K
# Waiting for VTI to go from 200.02K to 200.0K
# Waiting for VTI to go from 200.02K to 200.0K
# Waiting for VTI to go from 200.03K to 200.0K
# Waiting for VTI to go from 200.01K to 200.0K
# Waiting for VTI to go from 200.01K to 200.0K
# Waiting for VTI to go from 200.01K to 200.0K
# Waiting for VTI to go from 200.0K to 200.0K

# %%
#LK336.set_sample_temp(300)

#This one doesn't work because of a hardware issue, I promise

# %% [markdown]
# # Magnet

# %% [markdown]
# ### Sub-driver

# %%
import sys
module_dir = r"D:\SagnacOperatingSys\VecMagSagnac_control"
sys.path.append(module_dir)
from sagnac.magnet_safe_ramp_hermes import MagPowSup

MPS1 = MagPowSup("169.254.62.187")
MPS2 = MagPowSup("169.254.62.188")
# Out:
# sagnac4.0: no magnet 4G
# Make sure you have confirmed use of this driver with Kelly or Ethan before continuing for safety

# %%
MPS1.query("*IDN?")
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 MPS1.query("*IDN?")
#
# File D:\SagnacOperatingSys\VecMagSagnac_control\sagnac\magnet_safe_ramp_hermes.py:27, in MagPowSup.query(self, command)
#      26 def query(self, command):
# ---> 27     return self.instrument.query(command)
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\resources\messagebased.py:647, in MessageBasedResource.query(self, message, delay)
#     644 if delay > 0.0:
#     645     time.sleep(delay)
# --> 647 return self.read()
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\resources\messagebased.py:485, in MessageBasedResource.read(self, termination, encoding)
#     483 if termination is None:
#     484     termination = self._read_termination
# --> 485     message = self._read_raw().decode(enco)
#     486 else:
#     487     with self.read_termination_context(termination):
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\resources\messagebased.py:441, in MessageBasedResource._read_raw(self, size)
#     434     while status == loop_status:
#     435         logger.debug(
#     436             "%s - reading %d bytes (last status %r)",
#     437             self._resource_name,
#     438             size,
#     439             status,
#     440         )
# --> 441         chunk, status = self.visalib.read(self.session, size)
#     442         ret.extend(chunk)
#     443 except errors.VisaIOError as e:
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\ctwrapper\functions.py:2336, in read(library, session, count)
#    2334 buffer = create_string_buffer(count)
#    2335 return_count = ViUInt32()
# -> 2336 ret = library.viRead(session, buffer, count, byref(return_count))
#    2337 return buffer.raw[: return_count.value], ret
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File c:\Users\luogroup\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
MPS1.write("SWEEP ZERO")
MPS2.write("SWEEP ZERO")

# %%
# MPS2.query("*IDN?")
# Out:
# 'Cryomagnetics,4G,8835,1.67,327'

# %%
# for i in range(int(2)):
#     MPS2.set_channel(f"{i+1}")
#     response = MPS2.get_field()
#     print(response)
# Out:
# 0.0
# 0.0

# %% [markdown]
# ### Magnet using Safe Ramp Hermes

# %%
from aparatus.sagnac4 import mag

mag.connect()
# Out:
# 2025-04-29 18:23:41,915 - WARNING - Failed to import vxi11 package, which is required for the VXI11Adapter
# Connecting. The field is 0.001

# %%
mag.Bx = 0.01
mag.By = 0
mag.Bz = 0

mag.setSafe_wait()
# Out:
# Bx, By, Bz is currently 0.0,0.0,0.0
# Field is close to the setpoint (I owe my existence to Ethan Berg, all hail o7)
# Bx, By, Bz is currently 0.0,0.0,0.0
# I don't think the field is close enough
# waiting for mag for 6.695577383041382
# Bx, By, Bz is currently 0.0,0.0,0.0
# I don't think the field is close enough
# waiting for mag for 10.037105798721313
# Bx, By, Bz is currently 0.009,0.0,0.0
# Field is close to the setpoint (I owe my existence to Ethan Berg, all hail o7)

# %%
mag.phi = 0
mag.theta = 0
mag.B = 0

mag.setSafe_wait()
# Out:
# Bx, By, Bz is currently -1.414,-1.414,-0.069
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 6.325707674026489
# Bx, By, Bz is currently -1.414,-1.414,-0.041
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 9.60680103302002
# Bx, By, Bz is currently -1.414,-1.414,0.033
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 13.159489631652832
# Bx, By, Bz is currently -1.414,-1.414,0.044
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 16.455559968948364
# Bx, By, Bz is currently -1.414,-1.414,0.03
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 19.904473781585693
# Bx, By, Bz is currently -1.414,-1.414,0.011
# I don't think the field is close enough
# waiting for z to ramp down
# waiting for z to ramp down 23.478156089782715
# Bx, By, Bz is currently -1.414,-1.414,0.005
# Field is close to the setpoint (I owe my existence to Ethan Berg, all hail o7)
# Bx, By, Bz is currently -1.414,-1.414,0.005
# I don't think the field is close enough
# waiting for mag for 28.25877356529236
# Bx, By, Bz is currently -1.397,-1.414,0.003
# I don't think the field is close enough
# waiting for mag for 32.4655818939209
# Bx, By, Bz is currently -1.271,-1.375,0.002
# I don't think the field is close enough
# waiting for mag for 36.61724615097046
# Bx, By, Bz is currently -1.128,-1.274,0.001
# I don't think the field is close enough
# waiting for mag for 40.68853402137756
# Bx, By, Bz is currently -0.943,-1.183,0.0
# I don't think the field is close enough
# waiting for mag for 44.62647199630737
# Bx, By, Bz is currently -0.84,-1.08,0.0
# I don't think the field is close enough
# waiting for mag for 48.55561661720276
# Bx, By, Bz is currently -0.634,-0.989,0.0
# I don't think the field is close enough
# waiting for mag for 52.504034757614136
# Bx, By, Bz is currently -0.51,-0.886,0.0
# I don't think the field is close enough
# Woah magnet temp is higher than 4.300000000000001. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.35 to 4.300000000000001
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.37 to 4.15
# Mag ramp now set to Pause
# Mag ramp now set to Pause
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.41 to 4.15
# Bx, By, Bz is currently -0.172,-0.683,0.001
# I don't think the field is close enough
# Woah magnet temp is higher than 4.4. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.42 to 4.4
# Magnet is too hot, stop this, call Ethan ASAP before ramping magnet or Kelly
# Bx, By, Bz is currently -0.168,-0.676,0.001
# I don't think the field is close enough
# Woah magnet temp is higher than 4.300000000000001. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.39 to 4.300000000000001
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.38 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.37 to 4.15
# Bx, By, Bz is currently -0.166,-0.666,0.0
# I don't think the field is close enough
# Woah magnet temp is higher than 4.300000000000001. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.35 to 4.300000000000001
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.34 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.32 to 4.15
# Bx, By, Bz is currently -0.168,-0.666,0.0
# I don't think the field is close enough
# Woah magnet temp is higher than 4.300000000000001. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.31 to 4.300000000000001
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.3 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.28 to 4.15
# Bx, By, Bz is currently -0.168,-0.667,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.27 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.26 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.25 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.24 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.23 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.23 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.21 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.21 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.2 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.2 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.19 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.19 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.18 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.18 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.17 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.17 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.16 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.16 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.16 to 4.15
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.16 to 4.15
# Bx, By, Bz is currently -0.168,-0.668,0.0
# I don't think the field is close enough
# Overheat flag is up
# Flag is up
# FLAG IS NOW RESET
# waiting for mag for 185.10756945610046
# Bx, By, Bz is currently -0.154,-0.668,0.0
# I don't think the field is close enough
# waiting for mag for 189.1764359474182
# Bx, By, Bz is currently -0.017,-0.631,0.0
# I don't think the field is close enough
# waiting for mag for 193.62356686592102
# Bx, By, Bz is currently -0.007,-0.532,0.0
# I don't think the field is close enough
# waiting for mag for 197.6470708847046
# Bx, By, Bz is currently -0.003,-0.428,0.0
# I don't think the field is close enough
# waiting for mag for 201.41015934944153
# Bx, By, Bz is currently -0.001,-0.337,0.0
# I don't think the field is close enough
# waiting for mag for 205.11724710464478
# Bx, By, Bz is currently -0.001,-0.247,0.0
# I don't think the field is close enough
# waiting for mag for 208.91990637779236
# Bx, By, Bz is currently -0.0,-0.156,0.0
# I don't think the field is close enough
# waiting for mag for 212.40924215316772
# Bx, By, Bz is currently -0.0,-0.067,0.0
# I don't think the field is close enough
# waiting for mag for 216.28258872032166
# Bx, By, Bz is currently -0.0,-0.017,0.0
# I don't think the field is close enough
# Woah magnet temp is higher than 4.300000000000001. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.31 to 4.300000000000001
# Overheat flag is up
# Flag is up
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.31 to 4.15
# Mag ramp now set to Pause
# Mag ramp now set to Pause
# Mag ramp now set to Pause
# Woah magnet temp is higher than 4.15. Pausing ramp to cool down.
# Waiting for magnet to cool from 4.3 to 4.15
# Bx, By, Bz is currently 0.0,0.001,0.0
# Field is close to the setpoint (I owe my existence to Ethan Berg, all hail o7)

# %% [markdown]
# ### Magnet HighZ Tester

# %%
from aparatus.sagnac4 import maghighZ

maghighZ.connecthighZ()
# Out:
# 2025-04-29 18:23:31,540 - WARNING - Failed to import vxi11 package, which is required for the VXI11Adapter
# Connecting. The field is 0.0
# Zeroing X magnet
# Zeroing Y magnet
# disconnecting from x and y for safety

# %% [markdown]
# # Keithley

# %%
from aparatus.sagnac3 import keith1
import time
time.sleep(50e-6)

# %%
keith1.source_current = 1e-3
keith1.source_current = 0

# %%
# keith1.source_current = 1e-5
# time.sleep(1)
keith1.source_current = 0
keith1.resistance

# %%
keith1.apply_current()
time.sleep(1)
print(f"done")

# %%
keith1.disable_source()

# %%
keith1.voltage[0]

# %%
keith2.voltage[0]

# %%
from pymeasure.instruments.keithley import Keithley2400
keithley = Keithley2400("GPIB::26")

# %%
# keithley.apply_current()# Sets up to source current
# keithley.source_current_range = 10e-3 # Sets the source current range to 10 mA

# %%
keithley.source_current

# %%
keithley.voltage

# %%
keithley.compliance_voltage = 10# Sets the compliance voltage to 10 V
keithley.source_current = 0 # Sets the source current to 0 mA
keithley.enable_source()# Enables the source output

keithley.measure_voltage()# Sets up to measure voltage

# keithley.ramp_to_current(5e-3)# Ramps the current to 5 mA
print(keithley.voltage)

# %%
# keith1 = Keithley2400("GPIB::26") #currently NI Max is reading as GPIB::26
# print(f"Check that output on Keithley is on")
keith1.enable_source()
keith1.measure_resistance()

# %% [markdown]
# # Pure Keithley

# %%
import sys
module_dir = r"C:\Users\luogroup\AppData\Roaming\Python\Python311\site-packages\pymeasure\instruments"
sys.path.append(module_dir)
from keithley.keithley2400 import Keithley2400

# %%
keith1 = Keithley2400("GPIB::26")

# %%
keith1.source_current = 1e-3
keith1.source_current = 0
