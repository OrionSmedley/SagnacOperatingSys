# %% [markdown]
# # Manual Control

# %%
from RedPPMS import ppms
# Out:
# 	Found QDInstrument.dll at C:\Users\jeral\anaconda3\Lib\site-packages\labdrivers\quantumdesign\QDInstrument.dll
# NoneType: None
#
# 	Found QDInstrument.dll at C:\Users\jeral\anaconda3\Lib\site-packages\labdrivers\quantumdesign\QDInstrument.dll
# NoneType: None
#
# 	Try right-clicking the .dll, selecting "Properties", and then clicking "Unblock"
# NoneType: None
#
# 	Try right-clicking the .dll, selecting "Properties", and then clicking "Unblock"
# NoneType: None

# %%
ppms.getTemperature()
# Out:
# (0, 60.4477, 6)

# %%
help(ppms.getTemperature)
# Out:
# Help on method getTemperature in module labdrivers.quantumdesign.qdinstrument:
#
# getTemperature() method of labdrivers.quantumdesign.qdinstrument.QdInstrument instance
#     Returns the instrument temperature in Kelvin.
#
#     Parameters are from:
#     SetTemperature(double Temperature, double Rate, QDInstrumentBase.TemperatureApproach Approach)
