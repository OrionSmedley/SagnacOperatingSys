# %%
# ramdon df
import pandas as pd
import numpy as np
import os

df = pd.DataFrame(np.random.randint(0, 100, size=(10, 4)), columns=list('ABCD'))

df
# Out:
#     A   B   C   D
# 0  37   3  71  16
# 1  24  81  55  93
# 2  97  83  78   8
# 3  92  50  84  69
# 4  57   9  95  91
# 5  53  39  12  37
# 6  13  80  76  21
# 7  34  75  31  72
# 8  75  94  93  18
# 9  78  45  16  18

# %%
savefile = 'initial.csv'

df.to_csv(saveFile, mode='a', header=not os.path.exists(saveFile), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 savefile = 'initial.csv'
# ----> 3 df.to_csv(saveFile, mode='a', header=not os.path.exists(saveFile), index=False)
#
# NameError: name 'saveFile' is not defined
