# %%
import numpy as np
import pandas as pd
# import plotly express
import plotly.express as px
def rename_columns(df):
    df.columns = [col.split('#')[-1].strip() if '#' in col else col for col in df.columns]
    return df

# %%
test = pd.read_csv("initial.csv", comment = ";")
print(test.columns)
# Apply the function to the dataframe
test = rename_columns(test)
print(test.columns)


# px.line(test, x='magnet.field', y=" dem(3)['x'] # X1", title='PtCo')
px.line(test, x='magnet.field', y="ThetaK", title='PtCo')
# Out:
# Index(['magnet.field', ' magnet.phi', ' magnet.theta', ' dem(3)['x'] # X1',
#        ' dem(3)['y'] # Y1', ' dem(2)['x'] # X2', ' dem(2)['y'] # Y2',
#        ' np.arctan(J2J1 * dem(3)['x'] / dem(2)['y']) / 2 # ThetaK'],
#       dtype='object')
# Index(['magnet.field', ' magnet.phi', ' magnet.theta', 'X1', 'Y1', 'X2', 'Y2',
#        'ThetaK'],
#       dtype='object')

# %%
np.linspace(0, 10, 100) 
#join to annother np array use as a lambda function
np.concatenate([np.linspace(0, 10, 100), np.linspace(0, 10, 100)])

# %%
import numpy as np
def hysteresis(npArray):
    return np.concatenate([npArray, npArray[::-1]])
hysteresis(np.linspace(-10, 10, 10+1))
# Out:
# array([-10.,  -8.,  -6.,  -4.,  -2.,   0.,   2.,   4.,   6.,   8.,  10.,
#         10.,   8.,   6.,   4.,   2.,   0.,  -2.,  -4.,  -6.,  -8., -10.])

# %%
(lambda x: np.concatenate) (5)
# Out:
# 25
