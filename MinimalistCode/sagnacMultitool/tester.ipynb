# %% [markdown]
# # Instrument
# can you import an instance dirrectly? yes

# %%
import numpy as np
from instruments.instrument import instrument

# Set parameters
instrument.phase = np.pi / 4
instrument.frequency = 10
instrument.temperature = 25

# Access properties
print("Voltage:", instrument.voltage)
print("Current:", instrument.current)
# Out:
# Voltage: 9.571067811865476
# Current: 8.321067811865476

# %%
from instruments import instrument

# %%
instrument.voltage
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[3], line 1
#
# ----> 1 instrument.voltage
#
#
#
# AttributeError: module 'instruments.instrument' has no attribute 'voltage'

# %% [markdown]
# # load variables
# Does experimenter.load_variables_from_csv work? Yes

# %%
import experimenter as exper
csv_file = 'dummy.csv'
parameters,headers,namespace = exper.load_variables_from_csv(csv_file=csv_file)

# %%
parameters
# Out:
# {'inst.phase': 0,
#  'inst.frequency': array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ]),
#  'inst.temperature': [25, 30, 35]}

# %%
headers
# Out:
# ['inst.voltage', ' inst.current', ' inst.junk']

# %%
namespace;

# %% [markdown]
# # Perform Measurement

# %%
# def perform_measurement(headers, namespace):
#     """Performs the measurement by evaluating the headers."""
#     data = {}
#     for header in headers:
#         obj = eval(header.strip(), namespace)
#         data[header] = obj() if callable(obj) else obj
#     return data

data = exper.perform_measurement(headers, namespace,csv_file = csv_file)
data
# Out:
# {'inst.voltage': np.float64(6.123233995736766e-16),
#  ' inst.current': np.float64(10.0),
#  ' inst.junk': 11}

# %%
import numpy as np
exper.set_parameter({'inst.frequency': 10,"inst.phase": np.pi/2 }, namespace)
exper.set_parameter({'inst.set_junk': 11 }, namespace)

# %%
# Make sure that doing the bad thing results in an error
exper.set_parameter({'inst.set_junky': 25 }, namespace)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Make sure that doing the bad thing results in an error
# ----> 2 exper.set_parameter({'inst.set_junky': 25 }, namespace)
#
# File c:\Users\Ralph Group\Documents\Github\SagnacOperatingSys\MinimalistCode\sagnacMultitool\experimenter.py:9, in set_parameter(non_list_variables, namespace)
#       6 """Set parameters dynamically, supporting method calls and attribute assignment."""
#       7 for name, value in non_list_variables.items():
#       8     # Resolve the name into an object
# ----> 9     obj = eval(name, namespace)
#      11     # If the object is callable, call it with the value
#      12     if callable(obj):
#
# File <string>:1
#
# AttributeError: 'Instrument' object has no attribute 'set_junky'
